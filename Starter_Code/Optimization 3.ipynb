# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("../Resources/charity_data.csv")
application_df.head(14)
# Out:
#          EIN                                               NAME  \
# 0   10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1   10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2   10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3   10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4   10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# 5   10556855  MINORITY ORGAN & TISSUE TRANSPLANT & EDUCATION...
# 6   10558440  FRIENDS OF ARTS COUNCIL OF GREATER DENHAM SPRI...
# 7   10566033                          ISRAEL EMERGENCY ALLIANCE
# 8   10570430                                   ARAMCO BRATS INC
# 9   10571689         INTERNATIONAL ASSOCIATION OF FIRE FIGHTERS
# 10  10573059                      KAI ELUA OUTRIGGER CANOE CLUB
# 11  10575727                                   HERITAGE ACADEMY
# 12  10583569                   THE UNITED STATES PONY CLUBS INC
# 13  10585206  DOMINION INTERNATIONAL NETWORK OF MINISTRIES &...
#
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
new_df = application_df.drop(columns= ['EIN','NAME'])
new_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
new_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
new_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
## My cutoff value is 200
application_types_to_replace = ['T9','T13','T12','T2','T25','T14','T29','T15','T17'] 
# Replace in dataframe
for app in application_types_to_replace:
    new_df['APPLICATION_TYPE'] = new_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
new_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
new_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1728        1
# C2170        1
# C1283        1
# C1732        1
# C6100        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
new_df['CLASSIFICATION'].value_counts()[new_df['CLASSIFICATION'].value_counts()>1]
dataframe = pd.DataFrame(new_df['CLASSIFICATION'].value_counts())
dataframe
# Out:
#        CLASSIFICATION
# C1000           17326
# C2000            6074
# C1200            4837
# C3000            1918
# C2100            1883
# ...               ...
# C1728               1
# C2170               1
# C1283               1
# C1732               1
# C6100               1
#
# [71 rows x 1 columns]

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#cutoff value is 700
#  YOUR CODE GOES HERE
classifications_to_replace =[]

for row in dataframe.index:
    yikes = row
    classifications_to_replace.append(yikes)

classifications_to_replace2 = classifications_to_replace[5:71]
    
# Replace in dataframe
for cls in classifications_to_replace2:
    new_df['CLASSIFICATION'] = new_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
new_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
datafram2 = pd.DataFrame(new_df['ASK_AMT'].value_counts())
print(len(datafram2))
# Out:
# 8747

# %%
# Choose a cutoff value and create a list of ASK_AMT to be replaced
# use the variable name `ASK_AMT_to_replace`
#cutoff value is 3
#  YOUR CODE GOES HERE
ASK_AMT_to_replace =[]

for row in datafram2.index:
    yikes = row
    ASK_AMT_to_replace.append(yikes)

ASK_AMT_to_replace2 = ASK_AMT_to_replace[5:8747]
    
# Replace in dataframe
for cls in ASK_AMT_to_replace2:
    new_df['ASK_AMT'] = new_df['ASK_AMT'].replace(cls,"Other")
    
# Check to make sure binning was successful
new_df['ASK_AMT'].value_counts()
# Out:
# 5000     25398
# Other     8889
# 15583        3
# 6725         3
# 63981        3
# 10478        3
# Name: ASK_AMT, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
count_dummy = pd.get_dummies(new_df)
count_dummy
# Out:
#        STATUS  IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0           1              1                       0                     1
# 1           1              1                       0                     0
# 2           1              0                       0                     0
# 3           1              1                       0                     0
# 4           1              1                       0                     0
# ...       ...            ...                     ...                   ...
# 34294       1              0                       0                     0
# 34295       1              0                       0                     0
# 34296       1              0                       0                     0
# 34297       1              1                       0                     0
# 34298       1              0                       0                     0
#
# ...

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y = count_dummy['IS_SUCCESSFUL'].values
X = count_dummy.drop(columns = ['IS_SUCCESSFUL']).values
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 7

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))
# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))
# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 8)                 392
#
#  dense_1 (Dense)             (None, 7)                 63
#
#  dense_2 (Dense)             (None, 1)                 8
#
# ...
# Total params: 463
# Trainable params: 463
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.6195 - accuracy: 0.6856
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5687 - accuracy: 0.7272
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5614 - accuracy: 0.7299
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5584 - accuracy: 0.7298
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5567 - accuracy: 0.7310
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5553 - accuracy: 0.7306
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5542 - accuracy: 0.7322
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5536 - accuracy: 0.7321
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5529 - accuracy: 0.7318
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5557 - accuracy: 0.7234 - 330ms/epoch - 1ms/step
# Loss: 0.5557082891464233, Accuracy: 0.7233819365501404

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save_weights('AlphabetSoupCharityOptimization3.hdf5')
